# %%
beta_patterns = '''VVF
EISTTDAIFVQ
KQV
TRLVLVNALYFN
HRRLFH
TVSVPMMAQTNKFNYTEFT
YYDILELP
LSMFIAAP
TRLPRLLVLP
FSLETEVD
HVAQ
LQKVKIEV
EEII
FLFVVRH
TVLFMGQV'''

alpha_patterns = '''PPSYVAHLASDFGVRVFQQVAQA
PYGVASVLAMLQLT
GETQQQIQAAM
MAPALRHLYKELM
PWN
FMPHFFRLF
VERARFIINDWVKTH
DSS
SALT
AQLISHWKG
RKPLEN
DMF'''

patterns = []

for beta_pattern in beta_patterns.split('\n'):
    patterns.append([beta_pattern, 'B'])
    
for alpha_pattern in alpha_patterns.split('\n'):
    patterns.append([alpha_pattern, 'A'])
# Out:
# [['VVF', 'B'],
#  ['EISTTDAIFVQ', 'B'],
#  ['KQV', 'B'],
#  ['TRLVLVNALYFN', 'B'],
#  ['HRRLFH', 'B'],
#  ['TVSVPMMAQTNKFNYTEFT', 'B'],
#  ['YYDILELP', 'B'],
#  ['LSMFIAAP', 'B'],
#  ['TRLPRLLVLP', 'B'],
#  ['FSLETEVD', 'B'],
#  ['HVAQ', 'B'],
#  ['LQKVKIEV', 'B'],
#  ['EEII', 'B'],
#  ['FLFVVRH', 'B'],
#  ['TVLFMGQV', 'B'],
#  ['PPSYVAHLASDFGVRVFQQVAQA', 'A'],
#  ['PYGVASVLAMLQLT', 'A'],
#  ['GETQQQIQAAM', 'A'],
#  ['MAPALRHLYKELM', 'A'],
#  ['PWN', 'A'],
#  ['FMPHFFRLF', 'A'],
#  ['VERARFIINDWVKTH', 'A'],
#  ['DSS', 'A'],
#  ['SALT', 'A'],
#  ['AQLISHWKG', 'A'],
#  ['RKPLEN', 'A'],
#  ['DMF', 'A']]

# %%
seq = '...'

# %%
for row in patterns:
    pattern = row[0]
    pat_type = row[1]
    
    start = seq.find(pattern)
    stop = start + len(pattern) - 1
    length = stop - start + 1
    
    print("Pattern: '{}'\nType: {}".format(pattern, pat_type))
    print("Coords: {}-{}\tLength: {}\n".format(start, stop, length))
# Out:
# Pattern: 'VVF'
# Type: B
# Coords: 54-56	Length: 3
#
# Pattern: 'EISTTDAIFVQ'
# Type: B
# Coords: 112-122	Length: 11
#
# Pattern: 'KQV'
# Type: B
# Coords: 144-146	Length: 3
#
# Pattern: 'TRLVLVNALYFN'
# Type: B
# Coords: 183-194	Length: 12
#
# Pattern: 'HRRLFH'
# Type: B
# Coords: 207-212	Length: 6
#
# Pattern: 'TVSVPMMAQTNKFNYTEFT'
# Type: B
# Coords: 218-236	Length: 19
#
# Pattern: 'YYDILELP'
# Type: B
# Coords: 242-249	Length: 8
#
# Pattern: 'LSMFIAAP'
# Type: B
# Coords: 255-262	Length: 8
#
# Pattern: 'TRLPRLLVLP'
# Type: B
# Coords: 289-298	Length: 10
#
# Pattern: 'FSLETEVD'
# Type: B
# Coords: 300-307	Length: 8
#
# Pattern: 'HVAQ'
# Type: B
# Coords: 338-341	Length: 4
#
# Pattern: 'LQKVKIEV'
# Type: B
# Coords: 343-350	Length: 8
#
# Pattern: 'EEII'
# Type: B
# Coords: 372-375	Length: 4
#
# Pattern: 'FLFVVRH'
# Type: B
# Coords: 380-386	Length: 7
#
# Pattern: 'TVLFMGQV'
# Type: B
# Coords: 391-398	Length: 8
#
# Pattern: 'PPSYVAHLASDFGVRVFQQVAQA'
# Type: A
# ...
